# %% [markdown]
# ### Puxar base de dados

# %%
import pandas as pd

exportacao_df = pd.read_csv("exportacoes_franca.csv")
exportacao_df = exportacao_df.loc[exportacao_df['Economic Block']=='Europe', :]
display(exportacao_df)
# Out:
#         Year  Month Country                         City  SH4 Code  \
# 0       2016      1  France            Águas Mornas - SC       303
# 2       2016      1  France            Águas Mornas - SC       304
# 4       2016      1  France                 Alfenas - MG       901
# 6       2016      1  France           Alta Floresta - MT      4409
# 8       2016      1  France              Ananindeua - PA      1211
# ...      ...    ...     ...                          ...       ...
# 142350  2020     12  France                 Vinhedo - SP      4016
# 142352  2020     12  France                 Vinhedo - SP      6806
# 142354  2020     12  France                 Vinhedo - SP      8424
# 142356  2020     12  France  Vitória de Santo Antão - PE       714
# 142358  2020     12  France                  Xapuri - AC      4409
#
#                                           SH4 Description  SH2 Code  \
# 0       Fish, frozen, excluding fish fillets and other...         3
# ...

# %% [markdown]
# ### Informações Gerais

# %%
#exportacao_df.info

display(exportacao_df.describe())
# Out:
#                Year         Month      SH4 Code      SH2 Code       US$ FOB  \
# count  71180.000000  71180.000000  71180.000000  71180.000000  7.118000e+04
# mean    2018.065665      6.591922   6169.147246     61.516985  1.650039e+05
# std        1.407976      3.462356   2655.080787     26.471474  1.247209e+06
# min     2016.000000      1.000000    101.000000      1.000000  0.000000e+00
# 25%     2017.000000      4.000000   4009.000000     40.000000  4.170000e+02
# 50%     2018.000000      7.000000   7117.000000     71.000000  4.256500e+03
# 75%     2019.000000     10.000000   8483.000000     84.000000  3.710700e+04
# max     2020.000000     12.000000   9999.000000     99.000000  1.086352e+08
#
#          Net Weight
# count  7.118000e+04
# mean   6.500505e+05
# std    9.875945e+06
# min    0.000000e+00
# 25%    3.000000e+00
# 50%    3.800000e+01
# 75%    3.185000e+03
# max    7.100291e+08

# %% [markdown]
# ### Como foi a evolução das exportações para a frança ao longo dos anos?

# %%
exportacao_ano = exportacao_df.groupby("Year").sum()
exportacao_ano = exportacao_ano[['US$ FOB']]
def formartar(valor):
    return f"${valor:,.2f}"

exportacao_ano["US$ FOB"] = exportacao_ano["US$ FOB"].map(formartar)
display(exportacao_ano)
# Out:
#                 US$ FOB
# Year
# 2016  $2,307,750,041.00
# 2017  $2,224,352,728.00
# 2018  $2,619,712,208.00
# 2019  $2,609,361,806.00
# 2020  $1,983,797,405.00

# %% [markdown]
# ### Quais os produtos mais exportados ao longo de todo o período?

# %%
exportacao_produto = exportacao_df.groupby("SH4 Description").sum()
exportacao_produto = exportacao_produto[["US$ FOB","Net Weight"]]

exportacao_produto = exportacao_produto.sort_values("US$ FOB", ascending = False)

exportacao_produto["US$ FOB"] = exportacao_produto["US$ FOB"].map(formartar)
display(exportacao_produto)
# Out:
#                                                               US$ FOB  \
# SH4 Description
# Soybean oilcake and other solid residue, wh/not...  $2,814,212,320.00
# Iron ores and concentrates, including roasted i...  $1,632,140,244.00
# Chemical wood pulp, soda or sulphate, other tha...    $922,712,342.00
# Coffee, whether or not roasted or decaffeinated...    $536,277,376.00
# Other aircraft (for example, helicopters, aerop...    $342,566,535.00
# ...                                                               ...
# Anti-freezing preparations and prepared de-icin...              $5.00
# Man-made filament yarn (other than sewing threa...              $5.00
# Glass envelopes (including bulbs and tubes), op...              $4.00
# Cast glass and rolled glass, in sheets or profi...              $3.00
# Drawing or colouring books for children                         $3.00
#
#                                                      Net Weight
# SH4 Description
# ...

# %% [markdown]
# ### Em 2020 qual cidade mais exportou para a França?

# %%
exportacao_2020 = exportacao_df.loc[exportacao_df["Year"]==2020, :]

exportacao_city_2020 = exportacao_2020.groupby("City").sum()
exportacao_city_2020 = exportacao_city_2020[["US$ FOB"]]
exportacao_city_2020 = exportacao_city_2020.sort_values("US$ FOB", ascending = False)
exportacao_city_2020["US$ FOB"] = exportacao_city_2020["US$ FOB"].map(formartar)

display(exportacao_city_2020)
# Out:
#                                      US$ FOB
# City
# Duque de Caxias - RJ         $139,702,798.00
# Luís Eduardo Magalhães - BA  $132,664,066.00
# Ponta Grossa - PR             $93,888,508.00
# São José dos Campos - SP      $86,469,638.00
# Rio de Janeiro - RJ           $61,261,107.00
# ...                                      ...
# Não-Me-Toque - RS                     $21.00
# Cubatão - SP                          $20.00
# Holambra - SP                          $5.00
# São Sebastião do Caí - RS              $3.00
# Quatro Pontes - PR                     $0.00
#
# [648 rows x 1 columns]

# %% [markdown]
# ### O que as 2 maiores cidades exportaram tanto?

# %%
#Duque de caixias - RJ
exportacao_duque = exportacao_2020.loc[exportacao_2020["City"] == "Duque de Caxias - RJ",:]

exportacao_duque = exportacao_duque.groupby('SH4 Description').sum()

exportacao_duque = exportacao_duque[['US$ FOB']] 

exportacao_duque = exportacao_duque.sort_values("US$ FOB", ascending = False)

exportacao_duque["US$ FOB"] = exportacao_duque["US$ FOB"].map(formartar)

display(exportacao_duque)
# Out:
#                                                            US$ FOB
# SH4 Description
# Turbo-jets, turbo-propellers and other gas turb...  $82,490,516.00
# Crude oil from petroleum and bituminous minerals    $33,610,511.00
# Transmission shafts (including cam shafts and c...   $4,897,696.00
# Ball or roller bearings                              $4,123,545.00
# Screws, bolts, nuts, coach screws, screw hooks,...   $2,109,423.00
# Soybean oilcake and other solid residue, wh/not...   $2,007,137.00
# Other articles of nickel                             $1,475,623.00
# Other articles of iron or steel                      $1,423,564.00
# Taps, cocks, valves and similar appliances for ...   $1,028,261.00
# Articles of lead                                       $830,090.00
# Tubes, pipes and hollow profiles, seamless, of ...     $738,876.00
# Instruments and apparatus for measuring or chec...     $659,505.00
# Automatic regulating or controlling instruments...     $566,387.00
# ...
